# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities= []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url+city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng =city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | tura
# Processing Record 3 of Set 1 | palikir - national government center
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | kailua-kona
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | olonkinbyen
# Processing Record 12 of Set 1 | yeniseysk
# Processing Record 13 of Set 1 | iskateley
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | brignoles
# Processing Record 19 of Set 1 | prince rupert
# Processing Record 20 of Set 1 | margaret river
# Processing Record 21 of Set 1 | port mathurin
# Processing Record 22 of Set 1 | mersa matruh
# Processing Record 23 of Set 1 | kidal
# Processing Record 24 of Set 1 | puerto armuelles
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | cabedelo
# Processing Record 28 of Set 1 | blackmans bay
# Processing Record 29 of Set 1 | edinburgh of the seven seas
# Processing Record 30 of Set 1 | novaya igirma
# Processing Record 31 of Set 1 | vandergrift
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | leitchfield
# Processing Record 34 of Set 1 | izluchinsk
# Processing Record 35 of Set 1 | okhotsk
# Processing Record 36 of Set 1 | champerico
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | ballina
# Processing Record 39 of Set 1 | katsuren-haebaru
# Processing Record 40 of Set 1 | wailua homesteads
# Processing Record 41 of Set 1 | hawaiian paradise park
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | namibe
# Processing Record 44 of Set 1 | adamstown
# Processing Record 45 of Set 1 | tabou
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | harstad
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | aykhal
# Processing Record 0 of Set 2 | constantia
# Processing Record 1 of Set 2 | utrik
# Processing Record 2 of Set 2 | college
# Processing Record 3 of Set 2 | fort bragg
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | fort mcmurray
# Processing Record 6 of Set 2 | hotan
# Processing Record 7 of Set 2 | nogliki
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | torghay
# Processing Record 10 of Set 2 | wewak
# Processing Record 11 of Set 2 | pibor
# City not found. Skipping...
# Processing Record 12 of Set 2 | portland
# Processing Record 13 of Set 2 | atafu village
# Processing Record 14 of Set 2 | maragogi
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | vorgashor
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | san agustin de valle fertil
# Processing Record 20 of Set 2 | alaghsas
# Processing Record 21 of Set 2 | san jose village
# City not found. Skipping...
# Processing Record 22 of Set 2 | nar'yan-mar
# Processing Record 23 of Set 2 | nagar karnul
# Processing Record 24 of Set 2 | puerto natales
# Processing Record 25 of Set 2 | lihue
# Processing Record 26 of Set 2 | ararat
# Processing Record 27 of Set 2 | changping
# Processing Record 28 of Set 2 | esperanza
# Processing Record 29 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | stanley
# Processing Record 32 of Set 2 | liwa
# Processing Record 33 of Set 2 | nikolayevsk-on-amure
# Processing Record 34 of Set 2 | laguna
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | kande
# Processing Record 37 of Set 2 | pelabuhanratu
# Processing Record 38 of Set 2 | queenstown
# Processing Record 39 of Set 2 | camana
# Processing Record 40 of Set 2 | arendal
# Processing Record 41 of Set 2 | mejit
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | mangrol
# Processing Record 44 of Set 2 | kunyang
# Processing Record 45 of Set 2 | san antonio de pale
# Processing Record 46 of Set 2 | lycksele
# Processing Record 47 of Set 2 | las palmas de gran canaria
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | ranau
# Processing Record 0 of Set 3 | togur
# Processing Record 1 of Set 3 | tsengel
# Processing Record 2 of Set 3 | chinde
# Processing Record 3 of Set 3 | kuraymah
# Processing Record 4 of Set 3 | shortandy
# Processing Record 5 of Set 3 | caluula
# Processing Record 6 of Set 3 | qaqortoq
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | talcahuano
# Processing Record 10 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 11 of Set 3 | nova sintra
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | ust-nera
# Processing Record 14 of Set 3 | asau village
# City not found. Skipping...
# Processing Record 15 of Set 3 | manggar
# Processing Record 16 of Set 3 | dudinka
# Processing Record 17 of Set 3 | tolanaro
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | mount pearl
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | tosontsengel
# Processing Record 22 of Set 3 | hinthada
# Processing Record 23 of Set 3 | chonchi
# Processing Record 24 of Set 3 | trail
# Processing Record 25 of Set 3 | beledweyne
# Processing Record 26 of Set 3 | parkano
# Processing Record 27 of Set 3 | tauranga
# Processing Record 28 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 3 | tazovsky
# Processing Record 30 of Set 3 | hammerfest
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | brookings
# Processing Record 33 of Set 3 | isafjordur
# Processing Record 34 of Set 3 | jianshui
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | ingeniero jacobacci
# Processing Record 37 of Set 3 | kerikeri
# Processing Record 38 of Set 3 | hami
# Processing Record 39 of Set 3 | lupane
# Processing Record 40 of Set 3 | enewetak
# Processing Record 41 of Set 3 | helston
# Processing Record 42 of Set 3 | kalmunai
# Processing Record 43 of Set 3 | haiku-pauwela
# Processing Record 44 of Set 3 | teple
# Processing Record 45 of Set 3 | pont rouge
# Processing Record 46 of Set 3 | egilsstadir
# Processing Record 47 of Set 3 | sitionuevo
# Processing Record 48 of Set 3 | el colomo
# Processing Record 49 of Set 3 | chernyshevskiy
# Processing Record 0 of Set 4 | gazli
# Processing Record 1 of Set 4 | nouadhibou
# Processing Record 2 of Set 4 | anori
# Processing Record 3 of Set 4 | yeosu
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | mata-utu
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | christchurch
# Processing Record 8 of Set 4 | khandyga
# Processing Record 9 of Set 4 | fisterra
# Processing Record 10 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 11 of Set 4 | linxia chengguanzhen
# Processing Record 12 of Set 4 | new cairo
# City not found. Skipping...
# Processing Record 13 of Set 4 | weno
# Processing Record 14 of Set 4 | mili
# Processing Record 15 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 16 of Set 4 | novouzensk
# Processing Record 17 of Set 4 | kone
# Processing Record 18 of Set 4 | hadibu
# Processing Record 19 of Set 4 | yoloten
# Processing Record 20 of Set 4 | winnemucca
# Processing Record 21 of Set 4 | galesong
# Processing Record 22 of Set 4 | aroma
# Processing Record 23 of Set 4 | semenivka
# Processing Record 24 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | chibougamau
# Processing Record 27 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 28 of Set 4 | dhromolaxia
# Processing Record 29 of Set 4 | comodoro rivadavia
# Processing Record 30 of Set 4 | timbuktu
# Processing Record 31 of Set 4 | quellon
# Processing Record 32 of Set 4 | guozhen
# Processing Record 33 of Set 4 | porto novo
# Processing Record 34 of Set 4 | pangody
# Processing Record 35 of Set 4 | kapiri mposhi
# Processing Record 36 of Set 4 | raduzhny
# Processing Record 37 of Set 4 | borzya
# Processing Record 38 of Set 4 | inirida
# Processing Record 39 of Set 4 | gao
# Processing Record 40 of Set 4 | cozumel
# Processing Record 41 of Set 4 | santa cruz
# Processing Record 42 of Set 4 | sidi ifni
# Processing Record 43 of Set 4 | el granada
# Processing Record 44 of Set 4 | kauhajoki
# Processing Record 45 of Set 4 | basoko
# Processing Record 46 of Set 4 | cootamundra
# Processing Record 47 of Set 4 | kulhudhuffushi
# Processing Record 48 of Set 4 | puerto baquerizo moreno
# Processing Record 49 of Set 4 | sitka
# Processing Record 0 of Set 5 | gurupi
# Processing Record 1 of Set 5 | yambio
# Processing Record 2 of Set 5 | rawalpindi
# Processing Record 3 of Set 5 | haizhou
# Processing Record 4 of Set 5 | doume
# Processing Record 5 of Set 5 | connell
# Processing Record 6 of Set 5 | newman
# Processing Record 7 of Set 5 | invercargill
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | charters towers
# Processing Record 10 of Set 5 | cockburn town
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | petrovsk-zabaykal'skiy
# Processing Record 16 of Set 5 | nova vicosa
# Processing Record 17 of Set 5 | saipan
# Processing Record 18 of Set 5 | alice springs
# Processing Record 19 of Set 5 | ketchikan
# Processing Record 20 of Set 5 | labrador city
# Processing Record 21 of Set 5 | el matama
# Processing Record 22 of Set 5 | dapa
# Processing Record 23 of Set 5 | sile
# Processing Record 24 of Set 5 | mutuali
# Processing Record 25 of Set 5 | puerto ayora
# Processing Record 26 of Set 5 | thames
# Processing Record 27 of Set 5 | vesele
# Processing Record 28 of Set 5 | vadso
# Processing Record 29 of Set 5 | sandnessjoen
# Processing Record 30 of Set 5 | bereznik
# Processing Record 31 of Set 5 | badger
# Processing Record 32 of Set 5 | basavakalyan
# Processing Record 33 of Set 5 | bardai
# Processing Record 34 of Set 5 | mirny
# Processing Record 35 of Set 5 | pavilosta
# Processing Record 36 of Set 5 | uturoa
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | teterow
# Processing Record 39 of Set 5 | selfoss
# Processing Record 40 of Set 5 | karasburg
# Processing Record 41 of Set 5 | zemio
# Processing Record 42 of Set 5 | mount isa
# Processing Record 43 of Set 5 | keita
# Processing Record 44 of Set 5 | hamilton
# Processing Record 45 of Set 5 | 'anat al qadimah
# Processing Record 46 of Set 5 | laojunmiao
# Processing Record 47 of Set 5 | pitimbu
# Processing Record 48 of Set 5 | north bend
# Processing Record 49 of Set 5 | ghadamis
# Processing Record 0 of Set 6 | kampong speu
# Processing Record 1 of Set 6 | talnakh
# Processing Record 2 of Set 6 | pirai do sul
# Processing Record 3 of Set 6 | teguise
# Processing Record 4 of Set 6 | roma
# Processing Record 5 of Set 6 | tsiombe
# Processing Record 6 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 7 of Set 6 | tarare
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | bushland beach
# City not found. Skipping...
# Processing Record 10 of Set 6 | manaure
# Processing Record 11 of Set 6 | lagunas
# Processing Record 12 of Set 6 | mambajao
# Processing Record 13 of Set 6 | boende
# Processing Record 14 of Set 6 | akureyri
# Processing Record 15 of Set 6 | n'zeto
# Processing Record 16 of Set 6 | murun-kuren
# Processing Record 17 of Set 6 | lazaro cardenas
# Processing Record 18 of Set 6 | dauphin
# Processing Record 19 of Set 6 | dar chioukh
# Processing Record 20 of Set 6 | pimentel
# Processing Record 21 of Set 6 | praia da vitoria
# Processing Record 22 of Set 6 | sambava
# Processing Record 23 of Set 6 | vilyuchinsk
# Processing Record 24 of Set 6 | pasuquin
# Processing Record 25 of Set 6 | saint-pierre
# Processing Record 26 of Set 6 | canmore
# Processing Record 27 of Set 6 | usinsk
# Processing Record 28 of Set 6 | konarka
# Processing Record 29 of Set 6 | antsiranana
# Processing Record 30 of Set 6 | querqueville
# Processing Record 31 of Set 6 | xam nua
# Processing Record 32 of Set 6 | xiaogan
# Processing Record 33 of Set 6 | byron bay
# Processing Record 34 of Set 6 | yanchep
# Processing Record 35 of Set 6 | zhangye
# Processing Record 36 of Set 6 | veraval
# Processing Record 37 of Set 6 | erdenet
# Processing Record 38 of Set 6 | ad dawadimi
# Processing Record 39 of Set 6 | la sarre
# Processing Record 40 of Set 6 | ad dabbah
# Processing Record 41 of Set 6 | harnoli
# Processing Record 42 of Set 6 | santo antonio
# Processing Record 43 of Set 6 | fale old settlement
# Processing Record 44 of Set 6 | nongstoin
# Processing Record 45 of Set 6 | gunjur
# Processing Record 46 of Set 6 | kingston
# Processing Record 47 of Set 6 | batyrevo
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | axim
# Processing Record 0 of Set 7 | matthew town
# Processing Record 1 of Set 7 | kodiak
# Processing Record 2 of Set 7 | moree
# Processing Record 3 of Set 7 | severo-yeniseyskiy
# Processing Record 4 of Set 7 | illizi
# Processing Record 5 of Set 7 | tampakan
# Processing Record 6 of Set 7 | kapsan-up
# Processing Record 7 of Set 7 | tindouf
# Processing Record 8 of Set 7 | jitra
# Processing Record 9 of Set 7 | yung shue wan
# Processing Record 10 of Set 7 | horsham
# Processing Record 11 of Set 7 | xiahu
# Processing Record 12 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | peace river
# Processing Record 15 of Set 7 | nemuro
# Processing Record 16 of Set 7 | aasiaat
# Processing Record 17 of Set 7 | makokou
# Processing Record 18 of Set 7 | altamirano
# Processing Record 19 of Set 7 | anjiang
# Processing Record 20 of Set 7 | tonekabon
# Processing Record 21 of Set 7 | lugovoye
# Processing Record 22 of Set 7 | jinja
# Processing Record 23 of Set 7 | kharp
# Processing Record 24 of Set 7 | saint joseph
# Processing Record 25 of Set 7 | bandarbeyla
# Processing Record 26 of Set 7 | leava
# Processing Record 27 of Set 7 | chulucanas
# Processing Record 28 of Set 7 | al jawf
# Processing Record 29 of Set 7 | tual
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | dalandzadgad
# Processing Record 32 of Set 7 | luanda
# Processing Record 33 of Set 7 | hassi messaoud
# Processing Record 34 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 35 of Set 7 | kanal
# Processing Record 36 of Set 7 | lerwick
# Processing Record 37 of Set 7 | mandiana
# Processing Record 38 of Set 7 | garden city
# Processing Record 39 of Set 7 | bude
# Processing Record 40 of Set 7 | greymouth
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | mitu
# Processing Record 43 of Set 7 | kogalym
# Processing Record 44 of Set 7 | beyneu
# Processing Record 45 of Set 7 | kabansk
# Processing Record 46 of Set 7 | el daein
# City not found. Skipping...
# Processing Record 47 of Set 7 | vernon
# Processing Record 48 of Set 7 | luena
# Processing Record 49 of Set 7 | ta`u
# Processing Record 0 of Set 8 | iwanai
# Processing Record 1 of Set 8 | san francisco pujiltic
# Processing Record 2 of Set 8 | magadan
# Processing Record 3 of Set 8 | nkurenkuru
# City not found. Skipping...
# Processing Record 4 of Set 8 | san luis
# Processing Record 5 of Set 8 | grand forks
# Processing Record 6 of Set 8 | wellington
# Processing Record 7 of Set 8 | kampung sungai ara
# Processing Record 8 of Set 8 | zaragoza
# Processing Record 9 of Set 8 | lehre
# Processing Record 10 of Set 8 | butembo
# Processing Record 11 of Set 8 | rio grande
# Processing Record 12 of Set 8 | racine
# Processing Record 13 of Set 8 | martuk
# Processing Record 14 of Set 8 | saint-philippe
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | san lawrenz
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | bantay
# Processing Record 19 of Set 8 | peterhead
# Processing Record 20 of Set 8 | hengchun
# Processing Record 21 of Set 8 | kismayo
# Processing Record 22 of Set 8 | kandahar
# Processing Record 23 of Set 8 | kyren
# Processing Record 24 of Set 8 | san julian
# Processing Record 25 of Set 8 | naracoorte
# Processing Record 26 of Set 8 | nybro
# Processing Record 27 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 28 of Set 8 | hovd
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | natal
# Processing Record 31 of Set 8 | ataq
# Processing Record 32 of Set 8 | susuman
# Processing Record 33 of Set 8 | shpola
# Processing Record 34 of Set 8 | colonia
# Processing Record 35 of Set 8 | sola
# Processing Record 36 of Set 8 | port lincoln
# Processing Record 37 of Set 8 | uliastay
# Processing Record 38 of Set 8 | bamboo flat
# Processing Record 39 of Set 8 | borogontsy
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | tralee
# Processing Record 42 of Set 8 | klyuchi
# Processing Record 43 of Set 8 | dolinsk
# Processing Record 44 of Set 8 | callao
# Processing Record 45 of Set 8 | columbia falls
# Processing Record 46 of Set 8 | am timan
# Processing Record 47 of Set 8 | shingu
# Processing Record 48 of Set 8 | hendrina
# Processing Record 49 of Set 8 | polyarnyy
# Processing Record 0 of Set 9 | oyama
# Processing Record 1 of Set 9 | rio rancho
# Processing Record 2 of Set 9 | tefe
# Processing Record 3 of Set 9 | shenjiamen
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 5 of Set 9 | tevragh zeina
# City not found. Skipping...
# Processing Record 6 of Set 9 | aras-asan
# Processing Record 7 of Set 9 | pagar alam
# Processing Record 8 of Set 9 | kirensk
# Processing Record 9 of Set 9 | san andres
# Processing Record 10 of Set 9 | bull savanna
# Processing Record 11 of Set 9 | gadzhiyevo
# Processing Record 12 of Set 9 | whitby
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | bayanaul
# Processing Record 15 of Set 9 | mburucuya
# Processing Record 16 of Set 9 | hats'avan
# Processing Record 17 of Set 9 | pueblo
# Processing Record 18 of Set 9 | gereida
# Processing Record 19 of Set 9 | la passe
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | sabang
# Processing Record 22 of Set 9 | afaahiti
# Processing Record 23 of Set 9 | conceicao da barra
# Processing Record 24 of Set 9 | bargaal
# Processing Record 25 of Set 9 | bonthe
# Processing Record 26 of Set 9 | skovorodino
# Processing Record 27 of Set 9 | sabana yegua
# Processing Record 28 of Set 9 | svay rieng
# Processing Record 29 of Set 9 | hafar al-batin
# Processing Record 30 of Set 9 | taoudenni
# Processing Record 31 of Set 9 | edson
# Processing Record 32 of Set 9 | thurles
# Processing Record 33 of Set 9 | st. john's
# Processing Record 34 of Set 9 | vila velha
# Processing Record 35 of Set 9 | stephenville
# Processing Record 36 of Set 9 | al ghayzah
# Processing Record 37 of Set 9 | remire-montjoly
# Processing Record 38 of Set 9 | tidjikja
# Processing Record 39 of Set 9 | petauke
# Processing Record 40 of Set 9 | bhuj
# Processing Record 41 of Set 9 | arrifes
# Processing Record 42 of Set 9 | guacamayas
# Processing Record 43 of Set 9 | beaufort west
# Processing Record 44 of Set 9 | qusmuryn
# Processing Record 45 of Set 9 | jayapura
# Processing Record 46 of Set 9 | kangding
# Processing Record 47 of Set 9 | mil'kovo
# Processing Record 48 of Set 9 | las heras
# Processing Record 49 of Set 9 | 'alaqahdari dishu
# Processing Record 0 of Set 10 | sparti
# Processing Record 1 of Set 10 | masindi
# Processing Record 2 of Set 10 | zacharo
# Processing Record 3 of Set 10 | bhadasar
# Processing Record 4 of Set 10 | campo mourao
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | acarau
# Processing Record 7 of Set 10 | camiri
# Processing Record 8 of Set 10 | port douglas
# Processing Record 9 of Set 10 | ebon
# Processing Record 10 of Set 10 | yukhnov
# Processing Record 11 of Set 10 | skegness
# Processing Record 12 of Set 10 | andergrove
# Processing Record 13 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 14 of Set 10 | berlin
# Processing Record 15 of Set 10 | yashkul'
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | sanctuary point
# Processing Record 18 of Set 10 | dapitan
# Processing Record 19 of Set 10 | sake
# Processing Record 20 of Set 10 | corning
# Processing Record 21 of Set 10 | yantai
# Processing Record 22 of Set 10 | zalingei
# Processing Record 23 of Set 10 | akkol'
# Processing Record 24 of Set 10 | manghit
# Processing Record 25 of Set 10 | paoua
# Processing Record 26 of Set 10 | baranivka
# Processing Record 27 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 10 | khost
# Processing Record 29 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 30 of Set 10 | telavi
# Processing Record 31 of Set 10 | broome
# Processing Record 32 of Set 10 | imbituba
# Processing Record 33 of Set 10 | castillos
# Processing Record 34 of Set 10 | keflavik
# Processing Record 35 of Set 10 | moroni
# Processing Record 36 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 37 of Set 10 | acatlan de osorio
# Processing Record 38 of Set 10 | fortuna
# Processing Record 39 of Set 10 | severnoye
# Processing Record 40 of Set 10 | falmouth
# Processing Record 41 of Set 10 | new plymouth
# Processing Record 42 of Set 10 | kavarna
# Processing Record 43 of Set 10 | mont-laurier
# Processing Record 44 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 45 of Set 10 | edwards
# Processing Record 46 of Set 10 | guayaramerin
# Processing Record 47 of Set 10 | ubari
# Processing Record 48 of Set 10 | fayroz koh
# Processing Record 49 of Set 10 | arkhangel'sk
# Processing Record 0 of Set 11 | belokurikha
# Processing Record 1 of Set 11 | sagna
# Processing Record 2 of Set 11 | sishilichengzi
# City not found. Skipping...
# Processing Record 3 of Set 11 | lammi
# Processing Record 4 of Set 11 | ola
# Processing Record 5 of Set 11 | hargeysa
# Processing Record 6 of Set 11 | nhamunda
# Processing Record 7 of Set 11 | flying fish cove
# Processing Record 8 of Set 11 | kwaksan
# Processing Record 9 of Set 11 | el calafate
# Processing Record 10 of Set 11 | petrozavodsk
# Processing Record 11 of Set 11 | pingshan
# Processing Record 12 of Set 11 | yuzhno-kurilsk
# Processing Record 13 of Set 11 | juan griego
# Processing Record 14 of Set 11 | sach'khere
# City not found. Skipping...
# Processing Record 15 of Set 11 | andalgala
# Processing Record 16 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 17 of Set 11 | el sauzal de rodriguez
# Processing Record 18 of Set 11 | la gi
# Processing Record 19 of Set 11 | jiayuguan
# Processing Record 20 of Set 11 | macapa
# Processing Record 21 of Set 11 | nizhneangarsk
# Processing Record 22 of Set 11 | arno
# Processing Record 23 of Set 11 | dzhalagash
# Processing Record 24 of Set 11 | verkhnevilyuysk
# Processing Record 25 of Set 11 | ashburton
# Processing Record 26 of Set 11 | arica
# Processing Record 27 of Set 11 | galvan
# Processing Record 28 of Set 11 | agadez
# Processing Record 29 of Set 11 | raucesti
# Processing Record 30 of Set 11 | oyem
# Processing Record 31 of Set 11 | ha'il
# Processing Record 32 of Set 11 | dodoma
# Processing Record 33 of Set 11 | stettler
# Processing Record 34 of Set 11 | rethel
# Processing Record 35 of Set 11 | borovichi
# Processing Record 36 of Set 11 | mersing
# Processing Record 37 of Set 11 | touros
# Processing Record 38 of Set 11 | sergeyevka
# Processing Record 39 of Set 11 | kaele
# Processing Record 40 of Set 11 | mar del plata
# Processing Record 41 of Set 11 | taman rajawali
# City not found. Skipping...
# Processing Record 42 of Set 11 | howrah
# Processing Record 43 of Set 11 | cinisi
# Processing Record 44 of Set 11 | san luis de la loma
# Processing Record 45 of Set 11 | muisne
# Processing Record 46 of Set 11 | udachny
# Processing Record 47 of Set 11 | whakatane
# Processing Record 48 of Set 11 | tharangambadi
# Processing Record 49 of Set 11 | zigong
# Processing Record 0 of Set 12 | happy valley-goose bay
# Processing Record 1 of Set 12 | khanty-mansiysk
# Processing Record 2 of Set 12 | kiunga
# Processing Record 3 of Set 12 | kupino
# Processing Record 4 of Set 12 | cruzeiro do sul
# Processing Record 5 of Set 12 | isangel
# Processing Record 6 of Set 12 | villanueva
# Processing Record 7 of Set 12 | antalaha
# Processing Record 8 of Set 12 | meadow lakes
# Processing Record 9 of Set 12 | kapuskasing
# Processing Record 10 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 11 of Set 12 | namtsy
# Processing Record 12 of Set 12 | mizdah
# Processing Record 13 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 14 of Set 12 | shache
# Processing Record 15 of Set 12 | saldanha
# Processing Record 16 of Set 12 | piacabucu
# Processing Record 17 of Set 12 | kanniyakumari
# Processing Record 18 of Set 12 | playa vicente
# Processing Record 19 of Set 12 | morondava
# Processing Record 20 of Set 12 | lethem
# Processing Record 21 of Set 12 | sant lluis
# Processing Record 22 of Set 12 | port antonio
# Processing Record 23 of Set 12 | bodaybo
# Processing Record 24 of Set 12 | richards bay
# Processing Record 25 of Set 12 | sumiswald
# Processing Record 26 of Set 12 | nizhnyaya poyma
# Processing Record 27 of Set 12 | road town
# Processing Record 28 of Set 12 | valparaiso
# Processing Record 29 of Set 12 | archangelos
# Processing Record 30 of Set 12 | kisangani
# Processing Record 31 of Set 12 | nagqu
# Processing Record 32 of Set 12 | jijel
# Processing Record 33 of Set 12 | kodinsk
# Processing Record 34 of Set 12 | obonoma
# Processing Record 35 of Set 12 | goondiwindi
# Processing Record 36 of Set 12 | rumoi
# Processing Record 37 of Set 12 | lensk
# Processing Record 38 of Set 12 | betio village
# Processing Record 39 of Set 12 | punta umbria
# Processing Record 40 of Set 12 | monduli
# Processing Record 41 of Set 12 | penzance
# Processing Record 42 of Set 12 | vanino
# Processing Record 43 of Set 12 | lodja
# Processing Record 44 of Set 12 | chela
# Processing Record 45 of Set 12 | strelka
# Processing Record 46 of Set 12 | taupo
# Processing Record 47 of Set 12 | coahuayana de hidalgo
# Processing Record 48 of Set 12 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 49 of Set 12 | berdigestyakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Out:
# 0

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
#"Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Data"})

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                                    City      Lat       Lng  Max Temp  \
# 0                              waitangi -43.9535 -176.5597     12.12
# 1                                  tura  25.5198   90.2201     21.85
# 2  palikir - national government center   6.9248  158.1611     25.41
# 3                                bethel  41.3712  -73.4140      1.05
# 4                              hermanus -34.4187   19.2345     17.85
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        84           2        1.34      NZ  1699786522
# 1        83           2        1.00      IN  1699786523
# 2        94         100        1.54      FM  1699786524
# 3        81          40        0.00      US  1699786525
# 4        58          58        3.63      ZA  1699786526

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 0                                    waitangi -43.9535 -176.5597     12.12
# 1                                        tura  25.5198   90.2201     21.85
# 2        palikir - national government center   6.9248  158.1611     25.41
# 3                                      bethel  41.3712  -73.4140      1.05
# 4                                    hermanus -34.4187   19.2345     17.85
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              84           2        1.34      NZ  1699786522
# 1              83           2        1.00      IN  1699786523
# 2              94         100        1.54      FM  1699786524
# 3              81          40        0.00      US  1699786525
# 4              58          58        3.63      ZA  1699786526

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy.stats import linregress


def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
  
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    regress_values = x_values * slope + intercept

    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
northern_hemi_df.head()
# Display sample data
northern_hemi_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 1                                        tura  25.5198   90.2201     21.85
# 2        palikir - national government center   6.9248  158.1611     25.41
# 3                                      bethel  41.3712  -73.4140      1.05
# 5                                  georgetown   5.4112  100.3354     30.97
# 7                                 kailua-kona  19.6406 -155.9956     23.61
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 1              83           2        1.00      IN  1699786523
# 2              94         100        1.54      FM  1699786524
# 3              81          40        0.00      US  1699786525
# 5              70          20        2.57      MY  1699786527
# 7              91          40        1.54      US  1699786529

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
southern_hemi_df.head(5)

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597     12.12        84           2
# 4                 hermanus -34.4187   19.2345     17.85        58          58
# 6                grytviken -54.2811  -36.5092      3.47        95          66
# 9        port-aux-francais -49.3500   70.2167      4.07        91         100
# 14               papatowai -46.5619  169.4708     12.92        79          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      NZ  1699786522
# 4              3.63      ZA  1699786526
# 6              1.55      GS  1699786408
# 9             15.87      TF  1699786531
# 14             2.81      NZ  1699786537

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plt.title(f"Linear Regression on the Northern Hemisphere \n for Maximum Temperature")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(35,70))

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plt.title(f"Linear Regression on the Southern Hemisphere \n for Maximum Temperature")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plt.title(f"Linear Regression on the Northern Hemisphere \n for % Humidity")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,20))

# %%
# Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.title(f"Linear Regression on the Northern Hemisphere \n for % Cloudiness")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', 
                       '% Cloudiness',(46,29))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.title(f"Linear Regression on the Northern Hemisphere \n for % Cloudiness")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', 
                       '% Cloudiness',(46,29))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plt.title(f"Linear Regression on the Southern Hemisphere \n for % Cloudiness")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Cloudiness', 
                       '% Cloudiness',(-50,58))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plt.title("Linear Regression on the Northern Hemisphere \n for Wind Speed")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(5,33))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plt.title("Linear Regression on the Southern Hemisphere \n for Wind Speed")

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-22,29))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
